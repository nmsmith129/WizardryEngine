# %%
## code for generating random maps for use in Wizdrive
## Copyright 2025 Nicholas MacLean Smith
# %pip install -U ipykernel

import io
import sys

# %%
# Map element constants
WALL = 0b0
SPACE = 0b1
VISITED = 0b10
ITEM = 0b100
ENEMY = 0b1000
PLAYER = 0b10000
ENTRANCE = 0b100000
EXIT = 0b1000000

# %%
# Global Variables

width = 0
height = 0

# %%
def main():
    # redeclare global variables

    global width
    global height
    # ask user for map dimensions
    width = int(input("How wide should this map be in spaces? "))
    height = int(input("How tall should this map be in spaces? "))
    
    # Create widthxheight two-dimensional list
    try:
        map = [[0 for x in range(width)] for y in range(height)]
    except Exception as e:
        print(e)
        sys.quit(1)

    # levelFile = io.open("C:/Users/nmsmi/OneDrive/Documents/Coding projects/WizardryEngine/newlevelmap.lvlmap")

    # Set map entrance and exit

if __name__ == "__main__":
    main()
